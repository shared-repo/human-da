# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
# 데이터 준비
from sklearn.datasets import load_breast_cancer

bc_dataset = load_breast_cancer()

X = bc_dataset['data']
y = bc_dataset['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
# 모델 훈련 (학습)

from sklearn.svm import LinearSVC, SVC

lsvc = LinearSVC(random_state=42)
svc = SVC(C=10, gamma=0.0001)
lsvc.fit(X_train, y_train)
svc.fit(X_train, y_train)

print( lsvc.score(X_train, y_train), lsvc.score(X_test, y_test) )
print( svc.score(X_train, y_train), svc.score(X_test, y_test) )
# Out:
# 0.9694835680751174 0.958041958041958
# 0.9671361502347418 0.9440559440559441

# %%
# for n, i in zip(bc_dataset['feature_names'], rfc.feature_importances_):
#     print(n, i)

plt.barh(bc_dataset['feature_names'], rfc.feature_importances_)
plt.show()

# %%
# 모델 훈련
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(random_state=42)

gbc.fit(X_train, y_train)

gbc.score(X_train, y_train), gbc.score(X_test, y_test)
# Out:
# (1.0, 0.958041958041958)

# %%
plt.barh(bc_dataset['feature_names'], gbc.feature_importances_)
plt.show()
