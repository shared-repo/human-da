# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request # 웹 요청을 전송하고 응답을 수신하는 모듈 ( 브라우저 역할 )

# 서버로 전송하는 데이터
client_id = "IMXTCz5yqCWFa44uPpJN"
client_secret = "RBKLPIKygc"
encText = urllib.parse.quote("소년이온다")

# 요청 url + get 방식 전송 데이터 구성
url = "https://openapi.naver.com/v1/search/book.json?query={0}&display={1}".format(encText, 50)
request = urllib.request.Request(url)

# header에 전송 데이터 저장
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request) # 요청 보내기 + 응답 수신

rescode = response.getcode() # 응답코드 읽기
if(rescode==200): # 정상 응답이라면
    response_body = response.read() # 응답 데이터 읽기
    print(response_body.decode('utf-8')) # binary 데이터를 utf-8 text 데이터로 변환
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 22 Oct 2024 10:16:14 +0900",
# 	"total":10,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32491401626",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3249140\/32491401626.20231004072435.jpg",
# 			"author":"한강",
# 			"discount":"13500",
# 			"publisher":"창비",
# 			"pubdate":"20140519",
# 			"isbn":"9788936434120",
# ...

# %%
urllib.parse.quote("소년이온다")
# Out:
# '%EC%86%8C%EB%85%84%EC%9D%B4%EC%98%A8%EB%8B%A4'

# %%
'1번 {0}, 2번 {1}'.format('테스트', '연습')
# Out:
# '1번 테스트, 2번 연습'

# %%
text_response = response_body.decode('utf-8')

# %%
type( text_response )
# Out:
# str

# %%
# json str -> dict
import json

dict_response = json.loads(text_response)

print( type( dict_response ) )
# print( dict_response )

print ( type( dict_response['items'] ) )
# for item in dict_response['items']:
for idx, item in enumerate(dict_response['items']):
    # print(type(item))
    print("{0}. {1}".format(idx + 1, item['title']))
# Out:
# <class 'dict'>
# <class 'list'>
# 1. 소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)
# 2. 소년이 온다 1(큰글자도서) (한강 소설ㅣ2024년 노벨문학상 수상작가)
# 3. 소년이 온다 2(큰글자도서) (2024년 노벨문학상 수상작가)
# 4. Human Acts 한강 작가『소년이 온다』 영문판 (영국판) (소년이 온다)
# 5. Human Acts  한강 작가『소년이 온다』 영문판 (미국판) (소년이 온다)
# 6. 소년이 온다(특별한정판) (한강 소설ㅣ2024년 노벨문학상 수상작가)
# 7. 少年來了【新裝紀念版】 『소년이 온다』 대만판
# 8. Celui Qui Revient (한강 - 소년이 온다 프랑스어)
# 9. Atti umani (2024 노벨문학상 수상작가 한강 『소년이 온다』 이탈리아어판)
# 10. Human Acts 한강 작가『소년이 온다』 영문판 (영국판)

# %%
# titles = []
# for idx, item in enumerate(dict_response['items']):
#     titles.append(item['title'])

titles = [ item['title'] for item in dict_response['items'] ]

print(titles)
# Out:
# ['소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)', '소년이 온다 1(큰글자도서) (한강 소설ㅣ2024년 노벨문학상 수상작가)', '소년이 온다 2(큰글자도서) (2024년 노벨문학상 수상작가)', 'Human Acts 한강 작가『소년이 온다』 영문판 (영국판) (소년이 온다)', 'Human Acts  한강 작가『소년이 온다』 영문판 (미국판) (소년이 온다)', '소년이 온다(특별한정판) (한강 소설ㅣ2024년 노벨문학상 수상작가)', '少年來了【新裝紀念版】 『소년이 온다』 대만판', 'Celui Qui Revient (한강 - 소년이 온다 프랑스어)', 'Atti umani (2024 노벨문학상 수상작가 한강 『소년이 온다』 이탈리아어판)', 'Human Acts 한강 작가『소년이 온다』 영문판 (영국판)']

# %%
# dict : key : value
lv = ['abc', 'xyz', 'pqr']
dv = { 1: 'abc', 2: 'xyz', 3: 'pqr' } 
dv2 = { '11': 'abc', "22": 'xyz', '33': 'pqr' } 

print( lv[0] ) # list 에서 데이터 읽기 ( 순서번호 )
print( dv[1] ) # dict 에서 데이터 읽기 ( 키 )
print( dv2['11'] ) # dict 에서 데이터 읽기 ( 키 )
print( dict_response.keys() )
# Out:
# abc
# abc
# abc
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
! pip install pandas

# %%
import pandas as pd

df_response = pd.DataFrame(dict_response['items'])
print(type(df_response))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Kakao API 활용 연습

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request # 웹 요청을 전송하고 응답을 수신하는 모듈 ( 브라우저 역할 )

# 서버로 전송하는 데이터
api_key = "d521968522a7b6e1d1d38e13e83f1320"

encText = urllib.parse.quote("설현")
# 요청 url + get 방식 전송 데이터 구성
url = "https://dapi.kakao.com/v2/search/image?query={0}&size={1}".format(encText, 50)
request = urllib.request.Request(url)

# header에 전송 데이터 저장
# request.add_header("Authorization",f"KakaoAK ${api_key}")
request.add_header("Authorization","KakaoAK {0}".format(api_key))

response = urllib.request.urlopen(request) # 요청 보내기 + 응답 수신

rescode = response.getcode() # 응답코드 읽기
if(rescode==200): # 정상 응답이라면
    response_body = response.read() # 응답 데이터 읽기
    print(response_body.decode('utf-8')) # binary 데이터를 utf-8 text 데이터로 변환
else:
    print("Error Code:" + rescode)
# Out:
# {"documents":[{"collection":"news","datetime":"2021-09-14T23:45:22.000+09:00","display_sitename":"스포츠한국","doc_url":"http://v.media.daum.net/v/20210914234522455","height":540,"image_url":"https://t1.daumcdn.net/news/202109/14/SpoHankook/20210914234523497qmdp.jpg","thumbnail_url":"https://search1.kakaocdn.net/argon/130x130_85_c/4VPSdfN4KtR","width":540},{"collection":"news","datetime":"2024-04-13T14:35:41.000+09:00","display_sitename":"뉴스1","doc_url":"http://v.media.daum.net/v/20240413143541627","height":747,"image_url":"https://t1.daumcdn.net/news/202404/13/NEWS1/20240413143544341ogqk.jpg","thumbnail_url":"https://search4.kakaocdn.net/argon/130x130_85_c/H1Yxn0p2PQJ","width":594},{"collection":"news","datetime":"2024-09-11T14:06:12.000+09:00","display_sitename":"머니S","doc_url":"http://v.media.daum.net/v/20240911140612357","height":849,"image_url":"https://t1.daumcdn.net/news/202409/11/moneyweek/20240911140614153qaqr.jpg","thumbnail_url":"https://search4.kakaocdn.net/argon/130x130_85_c/
# ...

# %%
# json str -> dict
import json

text_response = response_body.decode('utf-8')
dict_response = json.loads(text_response)
dict_response
# Out:
# {'documents': [{'collection': 'news',
#    'datetime': '2021-09-14T23:45:22.000+09:00',
#    'display_sitename': '스포츠한국',
#    'doc_url': 'http://v.media.daum.net/v/20210914234522455',
#    'height': 540,
#    'image_url': 'https://t1.daumcdn.net/news/202109/14/SpoHankook/20210914234523497qmdp.jpg',
#    'thumbnail_url': 'https://search1.kakaocdn.net/argon/130x130_85_c/4VPSdfN4KtR',
#    'width': 540},
#   {'collection': 'news',
#    'datetime': '2024-04-13T14:35:41.000+09:00',
#    'display_sitename': '뉴스1',
#    'doc_url': 'http://v.media.daum.net/v/20240413143541627',
#    'height': 747,
#    'image_url': 'https://t1.daumcdn.net/news/202404/13/NEWS1/20240413143544341ogqk.jpg',
#    'thumbnail_url': 'https://search4.kakaocdn.net/argon/130x130_85_c/H1Yxn0p2PQJ',
#    'width': 594},
#   {'collection': 'news',
#    'datetime': '2024-09-11T14:06:12.000+09:00',
#    'display_sitename': '머니S',
#    'doc_url': 'http://v.media.daum.net/v/20240911140612357',
#    'height': 849,
# ...

# %%
print( dict_response.keys() )
# dict_response['documents']
print( type(dict_response['documents']) )

print( dict_response['documents'][0].keys() )

for document in dict_response['documents']:
    print(document['image_url'])
# Out:
# dict_keys(['documents', 'meta'])
# <class 'list'>
# dict_keys(['collection', 'datetime', 'display_sitename', 'doc_url', 'height', 'image_url', 'thumbnail_url', 'width'])
# https://t1.daumcdn.net/news/202109/14/SpoHankook/20210914234523497qmdp.jpg
# https://t1.daumcdn.net/news/202404/13/NEWS1/20240413143544341ogqk.jpg
# https://t1.daumcdn.net/news/202409/11/moneyweek/20240911140614153qaqr.jpg
# http://t1.daumcdn.net/news/201604/20/SpoChosun/20160420100600432bxyd.jpg
# https://t1.daumcdn.net/news/202005/21/segye/20200521222532922lssi.jpg
# http://t1.daumcdn.net/news/201512/16/SpoChosun/20151216085439463pdoz.jpg
# http://t1.daumcdn.net/news/201511/27/mbn/20151127224519128ponj.jpg
# http://t1.daumcdn.net/news/201508/24/sportskhan/20150824092122267naep.jpg
# https://t1.daumcdn.net/news/202404/09/moneyweek/20240409111157247icvm.jpg
# https://t1.daumcdn.net/news/202301/27/startoday/20230127131204127lthv.jpg
# http://t1.daumcdn.net/news/201603/28/SpoChosun/20160328090849626cdpa.jpg
# ...

# %%
df_documents = pd.DataFrame(dict_response['documents'])
df_documents['image_url']
# Out:
# 0     https://t1.daumcdn.net/news/202109/14/SpoHanko...
# 1     https://t1.daumcdn.net/news/202404/13/NEWS1/20...
# 2     https://t1.daumcdn.net/news/202409/11/moneywee...
# 3     http://t1.daumcdn.net/news/201604/20/SpoChosun...
# 4     https://t1.daumcdn.net/news/202005/21/segye/20...
# 5     http://t1.daumcdn.net/news/201512/16/SpoChosun...
# 6     http://t1.daumcdn.net/news/201511/27/mbn/20151...
# 7     http://t1.daumcdn.net/news/201508/24/sportskha...
# 8     https://t1.daumcdn.net/news/202404/09/moneywee...
# 9     https://t1.daumcdn.net/news/202301/27/startoda...
# 10    http://t1.daumcdn.net/news/201603/28/SpoChosun...
# 11    http://t1.daumcdn.net/news/201602/03/SpoChosun...
# 12    https://t1.daumcdn.net/news/202212/21/ilganspo...
# 13    http://t1.daumcdn.net/news/201601/09/ned/20160...
# 14    https://t1.daumcdn.net/news/202304/05/moneywee...
# 15    http://t1.daumcdn.net/news/201510/08/10asia/20...
# 16    https://t1.daumcdn.net/news/202008/09/sportskh...
# ...

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
from PIL import Image # 이미지 처리 모듈 + 클래스
from io import BytesIO # 메모리의 데이터를 파일처럼 사용하는 도구
import requests # urllib.request와 비슷한 기능을 수행하는 다른 모듈

response = requests.get(df_documents['image_url'][1])
if response.status_code == 200:
    image = Image.open(BytesIO(response.content))
    plt.imshow(image)
    plt.axis('off')
    plt.show()
else:
    print("error " + response.status_code)

# %% [markdown]
# #### 공공데이터포털의 날씨 데이터 서비스를 사용해서 특정 지역의 최근 1개월간 날씨 정보 조회
# #### 일별 최저, 최고, 평균 기온 표시
# #### 일별 평균 기온을 그래프로 표시 (선택)

# %%
import os
import sys
import urllib.request # 웹 요청을 전송하고 응답을 수신하는 모듈 ( 브라우저 역할 )

# 서버로 전송하는 데이터
api_key = "R%2BBEwJ49XVmTutdoCAdNq4m7wjOsdFNhVtlzkxWVeZJPhwQqWbGcD7CNeQPipFzIWAanQVw%2FrPLsGkfcYvD4AQ%3D%3D"

# 요청 url + get 방식 전송 데이터 구성
url = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?" + \
      "serviceKey={0}&pageNo={1}&numOfRows={2}&dataType={3}&dataCd={4}&dateCd={5}&startDt={6}&endDt={7}&stnIds={8}" \
      .format(api_key, 1, 40, "JSON", "ASOS", "DAY", '20240921', '20241021', 108)
request = urllib.request.Request(url)

response = urllib.request.urlopen(request) # 요청 보내기 + 응답 수신

rescode = response.getcode() # 응답코드 읽기
if(rescode==200): # 정상 응답이라면
    response_body = response.read() # 응답 데이터 읽기
    print(response_body.decode('utf-8')) # binary 데이터를 utf-8 text 데이터로 변환
else:
    print("Error Code:" + rescode)
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"stnId":"108","stnNm":"서울","tm":"2024-09-21","avgTa":"19.3","minTa":"17.1","minTaHrmt":"0749","maxTa":"21.9","maxTaHrmt":"1528","mi10MaxRn":"4.9","mi10MaxRnHrmt":"613","hr1MaxRn":"10.4","hr1MaxRnHrmt":"745","sumRnDur":"8.83","sumRn":"27.0","maxInsWs":"12.2","maxInsWsWd":"50","maxInsWsHrmt":"0747","maxWs":"7.0","maxWsWd":"50","maxWsHrmt":"0254","avgWs":"4.3","hr24SumRws":"3734","maxWd":"50","avgTd":"16.0","minRhm":"69","minRhmHrmt":"1741","avgRhm":"82.3","avgPv":"18.2","avgPa":"997.4","maxPs":"1008.9","maxPsHrmt":"2245","minPs":"1006.2","minPsHrmt":"1520","avgPs":"1007.3","ssDur":"12.2","sumSsHr":"0.0","hr1MaxIcsrHrmt":"1200","hr1MaxIcsr":"1.57","sumGsr":"6.31","ddMefs":"","ddMefsHrmt":"","ddMes":"","ddMesHrmt":"","sumDpthFhsc":"","avgTca":"8.5","avgLmac":"7.3","avgTs":"20.1","minTg":"15.9","avgCm5Te":"22.1","avgCm10Te":"22.2","avgCm20Te":"23.0","avgCm30Te":"24.1","avgM05
# ...

# %%
# json str -> dict
import json

text_response = response_body.decode('utf-8')
dict_response = json.loads(text_response)
dict_response
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'stnId': '108',
#       'stnNm': '서울',
#       'tm': '2024-09-21',
#       'avgTa': '19.3',
#       'minTa': '17.1',
#       'minTaHrmt': '0749',
#       'maxTa': '21.9',
#       'maxTaHrmt': '1528',
#       'mi10MaxRn': '4.9',
#       'mi10MaxRnHrmt': '613',
#       'hr1MaxRn': '10.4',
#       'hr1MaxRnHrmt': '745',
#       'sumRnDur': '8.83',
#       'sumRn': '27.0',
#       'maxInsWs': '12.2',
#       'maxInsWsWd': '50',
#       'maxInsWsHrmt': '0747',
#       'maxWs': '7.0',
#       'maxWsWd': '50',
#       'maxWsHrmt': '0254',
#       'avgWs': '4.3',
#       'hr24SumRws': '3734',
#       'maxWd': '50',
#       'avgTd': '16.0',
#       'minRhm': '69',
#       'minRhmHrmt': '1741',
#       'avgRhm': '82.3',
#       'avgPv': '18.2',
#       'avgPa': '997.4',
#       'maxPs': '1008.9',
#       'maxPsHrmt': '2245',
#       'minPs': '1006.2',
# ...

# %%
# 단계별로 접근하면서 데이터 구조 파악
dict_response['response'].keys()
dict_response['response']['body'].keys()
dict_response['response']['body']['items'].keys()
len( dict_response['response']['body']['items']['item'] )
# Out:
# 31

# %%
# 반복하면서 기온(max, min, avg) 데이터 뽑기
min_tas = []
max_tas = []
avg_tas = []
dates = []
for item in dict_response['response']['body']['items']['item']:
    # print( item['maxTa'], item['minTa'], item['avgTa'])
    min_tas.append( float(item['minTa']) )
    max_tas.append( float(item['maxTa']) )
    avg_tas.append( float(item['avgTa']) )
    dates.append(item['tm'])

# %%
len(min_tas), min_tas[:3]
# Out:
# (31, [17.1, 16.9, 16.6])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 3))
plt.plot(dates, avg_tas, label='avg')
plt.plot(dates, min_tas, label='min')
plt.plot(dates, max_tas, label='max')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
import requests

service_key = "R+BEwJ49XVmTutdoCAdNq4m7wjOsdFNhVtlzkxWVeZJPhwQqWbGcD7CNeQPipFzIWAanQVw/rPLsGkfcYvD4AQ=="
url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'
params ={'serviceKey' : service_key, 'pageNo' : 1, 'numOfRows' : 40, 'dataType' : 'JSON', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20240921', 'endDt' : '20241021', 'stnIds' : '108' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"stnId":"108","stnNm":"\xec\x84\x9c\xec\x9a\xb8","tm":"2024-09-21","avgTa":"19.3","minTa":"17.1","minTaHrmt":"0749","maxTa":"21.9","maxTaHrmt":"1528","mi10MaxRn":"4.9","mi10MaxRnHrmt":"613","hr1MaxRn":"10.4","hr1MaxRnHrmt":"745","sumRnDur":"8.83","sumRn":"27.0","maxInsWs":"12.2","maxInsWsWd":"50","maxInsWsHrmt":"0747","maxWs":"7.0","maxWsWd":"50","maxWsHrmt":"0254","avgWs":"4.3","hr24SumRws":"3734","maxWd":"50","avgTd":"16.0","minRhm":"69","minRhmHrmt":"1741","avgRhm":"82.3","avgPv":"18.2","avgPa":"997.4","maxPs":"1008.9","maxPsHrmt":"2245","minPs":"1006.2","minPsHrmt":"1520","avgPs":"1007.3","ssDur":"12.2","sumSsHr":"0.0","hr1MaxIcsrHrmt":"1200","hr1MaxIcsr":"1.57","sumGsr":"6.31","ddMefs":"","ddMefsHrmt":"","ddMes":"","ddMesHrmt":"","sumDpthFhsc":"","avgTca":"8.5","avgLmac":"7.3","avgTs":"20.1","minTg":"15.9","avgCm5Te":"22.1","avgCm10Te":"22.2","avgCm20Te":"23.0","a
# ...

# %%
# json str -> dict
import json

text_response = response.content.decode('utf-8')
dict_response = json.loads(text_response)
dict_response

# %%
import pandas as pd

df_weather = pd.DataFrame(dict_response['response']['body']['items']['item'])
df_weather.head(3)
# Out:
#   stnId stnNm          tm avgTa minTa minTaHrmt maxTa maxTaHrmt mi10MaxRn  \
# 0   108    서울  2024-09-21  19.3  17.1      0749  21.9      1528       4.9
# 1   108    서울  2024-09-22  21.0  16.9      0523  26.7      1520
# 2   108    서울  2024-09-23  20.8  16.6      0603  26.1      1544
#
#   mi10MaxRnHrmt  ... avgM05Te avgM10Te avgM15Te avgM30Te avgM50Te sumLrgEv  \
# 0           613  ...     27.3     26.5     25.9     21.7     19.1      1.8
# 1                ...     26.0     26.4     26.3     21.9     19.1      4.5
# 2                ...     25.6     26.1     26.2     22.1     19.1      4.5
#
#   sumSmlEv n99Rn                                               iscs sumFogDur
# 0      2.5   0.6  -{비}-0030. {비}0125-0250. {비}0310-{비}{강도0}0600-...
# 1      6.5
# 2      6.5
#
# [3 rows x 62 columns]

# %%
df_weather2 = df_weather[["tm", "minTa", "maxTa", "avgTa"]]
df_weather2.head(3)
# Out:
#            tm minTa maxTa avgTa
# 0  2024-09-21  17.1  21.9  19.3
# 1  2024-09-22  16.9  26.7  21.0
# 2  2024-09-23  16.6  26.1  20.8

# %%
df_weather2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tm      31 non-null     object
#  1   minTa   31 non-null     object
#  2   maxTa   31 non-null     object
#  3   avgTa   31 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
type( df_weather2['minTa'][0] ) # 컬럼의 데이터는 문자열
# Out:
# str

# %%
df_weather2['minTa2'] = df_weather2['minTa'].map(lambda v : float(v))
df_weather2['maxTa2'] = df_weather2['maxTa'].map(lambda v : float(v))
df_weather2['avgTa2'] = df_weather2['avgTa'].map(lambda v : float(v))

# %%
type( df_weather2['minTa'][0] ), type( df_weather2['minTa2'][0] )
# Out:
# (str, numpy.float64)

# %%
df_weather2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tm      31 non-null     object
#  1   minTa   31 non-null     object
#  2   maxTa   31 non-null     object
#  3   avgTa   31 non-null     object
#  4   minTa2  31 non-null     float64
#  5   maxTa2  31 non-null     float64
#  6   avgTa2  31 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 1.8+ KB

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 3))
plt.plot(df_weather2['tm'], df_weather2['avgTa2'], label='avg')
plt.plot(df_weather2['tm'], df_weather2['minTa2'], label='min')
plt.plot(df_weather2['tm'], df_weather2['maxTa2'], label='max')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
def f_add(a, b):
    return a + b

f_add(10, 20)

f_add2 = f_add # 함수를 변수에 저장

f_add2(20, 30)

def calc(f, a, b):
    return f(a, b)

calc(f_add, 100, 200) # 함수를 전달인자로 사용할 수 있습니다.
    
f_add3 = lambda a, b: a + b
calc(f_add3, 1000, 2000)

calc(lambda a, b: a + b, 1000, 2000)

# calc(def (a, b): return a + b, 1000, 2000)
# Out:
#   Cell In[103], line 20
#     calc(def (a, b): return a + b, 1000, 2000)
#          ^
# SyntaxError: invalid syntax
